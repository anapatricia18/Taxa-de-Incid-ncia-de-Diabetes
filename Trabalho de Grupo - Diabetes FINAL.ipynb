# %% [markdown]
# # Taxa de Incidência de Diabetes
# ### Trabalho de Grupo
#
# Docente: João Orvalho
#
# Discentes:
#  Ana Patricia a2020126703
#  Afonso Rodrigues a2020126731
#  David Poeira a2020131234

# %% [markdown]
# #### Proposta de Trabalho:
# Para esta proposta, em grupo decidimos avaliar a taxa de incidência de diabetes em Portugal no ano de 1992 e comparar com 2018.
# A razão pela qual escolhemos este tema para o trabalho, deve-se ao facto de ser um tema pouco abordado e acharmos necessário dar a conhecer mais sobre os dados e riscos desta doença.

# %%
import pandas as pd              #importar os pandas como pd
import matplotlib.pyplot as plt  #importar o matplotlib.pyplot para os gráficos como plt
import numpy as np               #importar os numpys como np

df_first = pd.read_csv("diabetes.csv")    #ler o primeiro conjunto de dados através dos pandas
df_first
# Out:
#      Ano  Sexo_Masculino  Sexo_Feminino  0_aos_4  5_aos_9  10_aos_14  \
# 0   1992      221.800000     259.400000     19.4      0.0        0.0
# 1   1993      246.900000     270.500000      0.0      0.0       25.0
# 2   1994      233.600000     296.800000     14.2     31.7       18.4
# 3   1995      236.900000     268.000000      0.0     10.6       17.9
# 4   1996      266.500000     307.900000      0.0     34.8       19.3
# 5   1997      284.400000     275.300000     15.4     12.3       20.7
# 6   1998      330.200000     288.300000      0.0     27.2       23.0
# 7   1999      286.500000     282.900000     15.9     27.1       35.0
# 8   2000      372.200000     382.100000     33.2      0.0        0.0
# 9   2003      414.700000     315.500000     16.9     49.2       31.2
# 10  2004      525.300000     449.900000     13.7     15.4       44.6
# 11  2005      640.200000     575.400000     17.6      0.0       16.6
# 12  2006      478.600000     444.500000      0.0      0.0       15.0
# 13  2007      550.200000     475.100000     17.0     34.0        0.0
# 14  2008      641.100000     527.800000      0.0      0.0        0.0
# 15  2009      606.900000     538.200000      0.0      0.0        0.0
# 16  2010      780.100000     568.100000      0.0      0.0        0.0
# 17  2011      724.800000     585.100000      0.0     56.1        0.0
# 18  2012      549.800000     456.300000      0.0      0.0        0.0
# 19  2013      522.400000     588.400000      0.0      0.0        0.0
# 20  2014      610.700000     443.200000      0.0      0.0        0.0
# 21  2015      764.489748     581.303176      0.0      0.0        0.0
# 22  2016      506.500000     462.600000      0.0      0.0        0.0
# 23  2017      572.000000     475.900000      0.0      0.0        0.0
# 24  2018      580.000000     627.000000      0.0      0.0        0.0
#
#     15_aos_24  25_aos_34   35_aos_44    45_aos_54    55_aos_64   65_aos_74  \
# 0         2.8       54.8  157.600000   535.200000   666.600000   729.40000
# 1        19.9       51.3  168.900000   587.000000   725.300000   622.00000
# 2        11.6       23.8  228.700000   511.800000   766.600000   715.60000
# 3        22.7       41.3  160.200000   470.600000   653.500000   697.40000
# 4        16.2       54.9  167.600000   487.800000   832.000000   828.90000
# 5        12.9       16.1  194.800000   553.000000   629.800000   891.70000
# 6        14.3       48.2  234.400000   668.100000   796.600000   833.10000
# 7         0.0       53.2  176.000000   454.900000   712.900000   830.60000
# 8        32.4       63.5  267.300000   597.500000   945.200000  1068.90000
# 9         6.5       95.4  287.200000   770.500000   762.600000   839.00000
# 10       56.0       60.6  355.800000   918.000000  1197.200000  1106.00000
# 11       42.2      102.5  478.100000  1060.100000  1372.200000  1433.20000
# 12       19.6       44.3  266.000000   674.400000  1224.100000  1194.50000
# 13       15.4       57.2  316.000000   792.900000  1338.700000  1260.20000
# 14       28.5       71.6  291.600000   908.000000  1374.900000  1419.80000
# 15        0.0       86.4  354.500000  1000.200000  1379.300000  1376.40000
# 16       42.2      117.4  302.900000   907.100000  1927.700000  1667.80000
# 17       27.0      117.0  351.600000   827.700000  1674.500000  1532.70000
# 18       30.7       69.5  280.100000   684.200000  1505.800000  1238.40000
# 19        0.0        0.0  156.200000   917.400000  1308.800000  1533.50000
# 20        0.0        0.0  184.000000   650.600000  1122.300000  1641.40000
# 21        0.0        0.0  186.282811  1062.391346  1555.275326  1456.31068
# 22        0.0        0.0  313.600000   763.400000   944.800000  1172.40000
# 23        0.0        0.0  149.900000   512.100000  1144.000000  1247.50000
# 24        0.0      113.0  229.000000   787.000000  1247.000000  1453.00000
#
#         75_mais       Total
# 0    353.900000  241.500000
# 1    447.800000  259.300000
# 2    406.100000  266.900000
# 3    449.100000  253.200000
# 4    399.700000  288.200000
# 5    473.100000  279.700000
# 6    341.100000  308.200000
# 7    572.600000  284.600000
# 8    581.500000  377.400000
# 9    498.500000  362.900000
# 10   879.500000  485.900000
# 11  1047.300000  606.400000
# 12   853.600000  460.800000
# 13   947.900000  511.100000
# 14  1160.400000  581.900000
# 15   896.900000  571.100000
# 16  1114.800000  669.200000
# 17  1210.900000  651.800000
# 18   821.400000  500.900000
# 19  1281.500000  557.100000
# 20  1207.000000  522.100000
# 21  1176.470588  667.653714
# 22   858.100000  483.300000
# 23  1571.200000  521.100000
# 24  1285.000000  605.000000

# %%
df_first.dtypes
# Out:
# Ano                 int64
# Sexo_Masculino    float64
# Sexo_Feminino     float64
# 0_aos_4           float64
# 5_aos_9           float64
# 10_aos_14         float64
# 15_aos_24         float64
# 25_aos_34         float64
# 35_aos_44         float64
# 45_aos_54         float64
# 55_aos_64         float64
# 65_aos_74         float64
# 75_mais           float64
# Total             float64
# dtype: object

# %%
b=df_first.describe()
b
# Out:
#                Ano  Sexo_Masculino  Sexo_Feminino    0_aos_4    5_aos_9  \
# count    25.000000       25.000000      25.000000  25.000000  25.000000
# mean   2005.280000      477.871590     429.820127   6.532000  11.936000
# std       8.193087      176.641345     124.749974   9.521017  17.503735
# min    1992.000000      221.800000     259.400000   0.000000   0.000000
# 25%    1998.000000      286.500000     296.800000   0.000000   0.000000
# 50%    2006.000000      522.400000     449.900000   0.000000   0.000000
# 75%    2012.000000      606.900000     538.200000  15.400000  27.100000
# max    2018.000000      780.100000     627.000000  33.200000  56.100000
#
#        10_aos_14  15_aos_24   25_aos_34   35_aos_44    45_aos_54    55_aos_64  \
# count  25.000000  25.000000   25.000000   25.000000    25.000000    25.000000
# mean   10.668000  16.036000   53.680000  250.331312   724.075654  1112.307013
# std    13.627415  16.011659   37.916509   83.442239   189.728469   359.159317
# min     0.000000   0.000000    0.000000  149.900000   454.900000   629.800000
# 25%     0.000000   0.000000   23.800000  176.000000   553.000000   766.600000
# 50%     0.000000  14.300000   54.800000  234.400000   684.200000  1144.000000
# 75%    19.300000  27.000000   71.600000  302.900000   907.100000  1372.200000
# max    44.600000  56.000000  117.400000  478.100000  1062.391346  1927.700000
#
#          65_aos_74      75_mais       Total
# count    25.000000    25.000000   25.000000
# mean   1151.588427   833.414824  452.690149
# std     326.064370   360.204940  146.440084
# min     622.000000   341.100000  241.500000
# 25%     833.100000   473.100000  288.200000
# 50%    1194.500000   858.100000  485.900000
# 75%    1433.200000  1160.400000  571.100000
# max    1667.800000  1571.200000  669.200000

# %% [markdown]
# #### Qual é o ano com a taxa de incidência de diabetes mais elevadas?

# %%
#ordenar os dados por ordem descendente a partir de uma coluna para ver qual o ano com mais pessoas com diabetes

df_first.sort_values(by=['Total'], ascending=False).head(1) 


#sort_values é uma função que ordena por defeito os dados por ordem ascendente através de uma coluna

#ascending=False faz com que a função ordene por ordem descendente 

#.head(1) = mostra apenas a primeira linha, ou seja, o ano com mais pessoas com diabetes
# Out:
#      Ano  Sexo_Masculino  Sexo_Feminino  0_aos_4  5_aos_9  10_aos_14  \
# 16  2010           780.1          568.1      0.0      0.0        0.0
#
#     15_aos_24  25_aos_34  35_aos_44  45_aos_54  55_aos_64  65_aos_74  75_mais  \
# 16       42.2      117.4      302.9      907.1     1927.7     1667.8   1114.8
#
#     Total
# 16  669.2

# %% [markdown]
# #### Qual é o ano com a taxa de incidência de diabetes menos elevadas?

# %%
#ordenar os dados por ordem ascendente a partir de uma coluna para ver qual qual o ano com menos pessoas com diabetes 
df_first.sort_values(by=['Total']).head(1)

#sem o ascending=False a função ordena por defeitos os valores de forma ascendente, o que também aconteceria se colocássemos ascending=True

#.head(1) = mostra apenas a primeira linha, ou seja, o ano com menos pessoas com diabetes
# Out:
#     Ano  Sexo_Masculino  Sexo_Feminino  0_aos_4  5_aos_9  10_aos_14  \
# 0  1992           221.8          259.4     19.4      0.0        0.0
#
#    15_aos_24  25_aos_34  35_aos_44  45_aos_54  55_aos_64  65_aos_74  75_mais  \
# 0        2.8       54.8      157.6      535.2      666.6      729.4    353.9
#
#    Total
# 0  241.5

# %% [markdown]
# #### Agora vamos comparar se existem mais pessoas do sexo masculino ou feminino com diabetes.
# Primeiramente, vamos determinar qual o maior e menor número de mulheres e homens que sabem ler, para assim conseguirmos trabalhar da melhor forma possível com as dimensões dos gráficos.

# %%
max_diab_Homens = df_first.Sexo_Masculino.max() #valor máximo da coluna Sexo_Masculino
min_diab_Homens = df_first.Sexo_Masculino.min() #valor mínimo da coluna Sexo_Masculino

max_diab_Mulheres = df_first.Sexo_Feminino.max() #valor máximo da coluna Sexo_Feminino
min_diab_Mulheres = df_first.Sexo_Feminino.min() #valor mínimo da coluna Sexo_feminino

print("Máximo sexo masculino com diabetes =",max_diab_Homens,";  Mínimo =", min_diab_Homens,";  Máximo sexo feminino com diabetes =", max_diab_Mulheres, ";  Mínimo =",min_diab_Mulheres,";")
# Out:
# Máximo sexo masculino com diabetes = 780.1 ;  Mínimo = 221.8 ;  Máximo sexo feminino com diabetes = 627.0 ;  Mínimo = 259.4 ;

# %% [markdown]
# #### Homens

# %%
import numpy as npw
import matplotlib.pyplot as plt #importar da biblioteca dados de gráficos

#dados para o gráfico
Anos = df_first ['Ano'].tolist() #transformar os valores da coluna Ano em uma lista numa única variável
homens= df_first['Sexo_Masculino'].tolist() #transformar os valores da coluna Sexo_Masculino em uma lista numa única variável

#definições do gráfico
plt.bar(Anos, homens, color="lightblue") #criar um gráfico de barras azul claro com os dados das colunas Anos(x)
plt.gcf().set_size_inches(20, 6) #função para trabalhar as dimensões do gráfico

#estilização do gráfico
plt.xticks(Anos) #título do eixo do x (linha horizontal)
plt.ylabel('Número do sexo masculino') #título do eixo do y (linha vertical)
plt.xlabel('Anos') #valores do eixo do x (todos os valores da coluna Anos)
plt.title('Número de homens por ano com diabetes') #título do gráfico
plt.show() #mostrar o gráfico de barras

# %% [markdown]
# #### Mulheres

# %%
import numpy as npw
import matplotlib.pyplot as plt #importar da biblioteca dados de gráficos

#dados para o gráfico
Anos = df_first ['Ano'].tolist() #transformar os valores da coluna Ano em uma lista numa única variável
mulheres= df_first['Sexo_Feminino'].tolist() #transformar os valores da coluna Sexo_Feminino em uma lista numa única variável

#definições do gráfico
plt.bar(Anos, mulheres, color="purple") #criar um gráfico de barras Roxo com os dados das colunas Anos(x)
plt.gcf().set_size_inches(20, 6) #função para trabalhar as dimensões do gráfico

#estilização do gráfico
plt.xticks(Anos) #título do eixo do x (linha horizontal)
plt.ylabel('Número do sexo feminino') #título do eixo do y (linha vertical)
plt.xlabel('Anos') #valores do eixo do x (todos os valores da coluna Anos)
plt.title('Número de mulheres por ano com diabetes') #título do gráfico
plt.show() #mostrar o gráfico de barras

# %% [markdown]
# #### Agora vamos calcular algumas médias importantes para compararmos o conjunto de dados.

# %%
media_homens_diab = df_first.Sexo_Masculino.mean() #média de todos os valores da coluna Sexo_Masculino
media_mulheres_diab = df_first.Sexo_Feminino.mean() #média de todos os valores da coluna Sexo_Feminino

media_homens_diab=round(media_homens_diab,2) #arredondar o resultado para 2 casas decimais
media_mulheres_diab=round(media_mulheres_diab,2) #arredondar o resultado para 2 casas decimais

print("Em Portugal, existe em média ",media_homens_diab , "de homens com diabetes e ", media_mulheres_diab, " de mulheres com diabetes entre os anos de 1992 e 2018.")
# Out:
# Em Portugal, existe em média  477.87 de homens com diabetes e  429.82  de mulheres com diabetes entre os anos de 1992 e 2018.

# %% [markdown]
# Com isto podemos concluir que entre 1992 e 2018, existem mais homens com diabetes em comparação às mulheres com esta mesma condição.

# %% [markdown]
# #### Será que houve alguma alteração entre os anos de 1992 a 2010?

# %%
result=df_first.sort_values(by=['Total'])
result_1 = result[(result.Ano >= 1992) & (result.Ano <= 2010)]
result_1[["Ano","Sexo_Masculino","Sexo_Feminino","Total"]]
# Out:
#      Ano  Sexo_Masculino  Sexo_Feminino  Total
# 0   1992           221.8          259.4  241.5
# 3   1995           236.9          268.0  253.2
# 1   1993           246.9          270.5  259.3
# 2   1994           233.6          296.8  266.9
# 5   1997           284.4          275.3  279.7
# 7   1999           286.5          282.9  284.6
# 4   1996           266.5          307.9  288.2
# 6   1998           330.2          288.3  308.2
# 9   2003           414.7          315.5  362.9
# 8   2000           372.2          382.1  377.4
# 12  2006           478.6          444.5  460.8
# 10  2004           525.3          449.9  485.9
# 13  2007           550.2          475.1  511.1
# 15  2009           606.9          538.2  571.1
# 14  2008           641.1          527.8  581.9
# 11  2005           640.2          575.4  606.4
# 16  2010           780.1          568.1  669.2

# %% [markdown]
# Com estes dados, foi possível verificar que passados 18 anos houve uma alteração ascendente nos números, ou seja, o algoritmo subiu drasticamente até ao ano de 2010.

# %% [markdown]
# #### E será que houve alguma alteração entre os anos de 2010 a 2018?

# %%
result=df_first.sort_values(by=['Total'], ascending=False )
result[["Ano","Sexo_Masculino","Sexo_Feminino","Total"]].head(5)
# Out:
#      Ano  Sexo_Masculino  Sexo_Feminino       Total
# 16  2010      780.100000     568.100000  669.200000
# 21  2015      764.489748     581.303176  667.653714
# 17  2011      724.800000     585.100000  651.800000
# 11  2005      640.200000     575.400000  606.400000
# 24  2018      580.000000     627.000000  605.000000

# %% [markdown]
# Podemos ver que passado 8 anos houve uma alteração significativa e os números foram descendo com o passar dos anos. Apesar de existir progressos desde 2010, houve uma evolução negativa no sexo feminino em 2018.

# %% [markdown]
# **Qual é a faixa etária com valores mais baixos de diabetes?**
#
# e
#
# **Qual é a faixa etária com valores mais altos de diabetes?**

# %% [markdown]
# Primeiramente, vamos verificar o valor mínimo e máximo de cada faixa etária.

# %%
a=b.loc["min"]
a
#a["0_aos_4","5_aos_9","10_aos_14","15_aos_24","25_aos_34","35_aos_44","45_aos_54","55_aos_64","65_aos_74","75_mais"].min()
# Out:
# Ano               1992.0
# Sexo_Masculino     221.8
# Sexo_Feminino      259.4
# 0_aos_4              0.0
# 5_aos_9              0.0
# 10_aos_14            0.0
# 15_aos_24            0.0
# 25_aos_34            0.0
# 35_aos_44          149.9
# 45_aos_54          454.9
# 55_aos_64          629.8
# 65_aos_74          622.0
# 75_mais            341.1
# Total              241.5
# Name: min, dtype: float64

# %%
a=b.loc["max"]
a
# Out:
# Ano               2018.000000
# Sexo_Masculino     780.100000
# Sexo_Feminino      627.000000
# 0_aos_4             33.200000
# 5_aos_9             56.100000
# 10_aos_14           44.600000
# 15_aos_24           56.000000
# 25_aos_34          117.400000
# 35_aos_44          478.100000
# 45_aos_54         1062.391346
# 55_aos_64         1927.700000
# 65_aos_74         1667.800000
# 75_mais           1571.200000
# Total              669.200000
# Name: max, dtype: float64

# %%
so_min=b.loc["min"]
so_min.drop(["Ano","Sexo_Masculino", "Sexo_Feminino", "Total"], inplace=True)
val_min=so_min.min()


so_max=b.loc["max"]
so_max.drop(["Ano","Sexo_Masculino", "Sexo_Feminino", "Total"], inplace=True)
val_max=so_max.max()


grupoEtario_min=so_min.loc[so_min == val_min].index[0]

grupoEtario_max=so_max.loc[so_max == val_max].index[0]

print('Faixa etária com valores mais baixos de diabetes: ' + grupoEtario_min + ' (' + str(val_min) + ')')
print('Faixa etária com valores mais altos de diabetes:  '+ grupoEtario_max + ' (' + str(val_max) + ')')
# Out:
# Faixa etária com valores mais baixos de diabetes: 0_aos_4 (0.0)
# Faixa etária com valores mais altos de diabetes:  55_aos_64 (1927.7)
